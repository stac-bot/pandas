# %% [markdown]
# <a href="https://colab.research.google.com/github/stac-bot/pandas/blob/master/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Loading data from kaggle

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-ce2b5d7f-7f02-4b69-b78e-c79d9744c0a3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ce2b5d7f-7f02-4b69-b78e-c79d9744c0a3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# {'kaggle.json': b'{"username":"ashutoshrudraksh","key":"180c7ef33a1ed44be18377bc640fdb29"}'}

# %%
! mkdir ~/.kaggle

# %%
! cp kaggle.json ~/.kaggle

# %%
! chmod 600 ~/.kaggle/kaggle.json

# %%
! kaggle datasets list
# Out:
# ...
# ref                                                         title                                              size  lastUpdated          downloadCount
# ----------------------------------------------------------  ------------------------------------------------  -----  -------------------  -------------
# gpreda/reddit-vaccine-myths                                 Reddit Vaccine Myths                              237KB  2021-12-12 11:59:54          18978
# crowww/a-large-scale-fish-dataset                           A Large Scale Fish Dataset                          3GB  2021-04-28 17:03:01          11566
# imsparsh/musicnet-dataset                                   MusicNet Dataset                                   22GB  2021-02-18 14:12:19           5945
# dhruvildave/wikibooks-dataset                               Wikibooks Dataset                                   2GB  2021-10-22 10:48:21           4031
# ...

# %%
# !kaggle datasets download -d maca11/all-pokemon-dataset
# Out:
# ...
#   0% 0.00/56.4k [00:00<?, ?B/s]
# 100% 56.4k/56.4k [00:00<00:00, 47.2MB/s]

# %%
# !unzip all-pokemon-dataset.zip
# Out:
# Archive:  all-pokemon-dataset.zip
#   inflating: All_Pokemon.csv

# %% [markdown]
# Loading the pokemon dataset

# %%
import pandas as pd

df = pd.read_csv(r'/content/All_Pokemon.csv')
#print(df.head(10))

df['HP'].head(20)

# %% [markdown]
# **Reading data in pandas**

# %%
### 
##read columns
df.columns
##which gives you the list of the columns name
# Out:
# Index(['Number', 'Name', 'Type 1', 'Type 2', 'Abilities', 'HP', 'Att', 'Def',
#        'Spa', 'Spd', 'Spe', 'BST', 'Mean', 'Standard Deviation', 'Generation',
#        'Experience type', 'Experience to level 100', 'Final Evolution',
#        'Catch Rate', 'Legendary', 'Mega Evolution', 'Alolan Form',
#        'Galarian Form', 'Against Normal', 'Against Fire', 'Against Water',
#        'Against Electric', 'Against Grass', 'Against Ice', 'Against Fighting',
#        'Against Poison', 'Against Ground', 'Against Flying', 'Against Psychic',
#        'Against Bug', 'Against Rock', 'Against Ghost', 'Against Dragon',
#        'Against Dark', 'Against Steel', 'Against Fairy', 'Height', 'Weight',
#        'BMI'],
#       dtype='object')

# %%
#read specific cloumn
print(df['Abilities'].head(10))
print(df[['Name','Att','Standard Deviation']].head(10))
# Out:
# 0    ['Chlorophyll', 'Overgrow']
# 1    ['Chlorophyll', 'Overgrow']
# 2    ['Chlorophyll', 'Overgrow']
# 3                  ['Thick Fat']
# 4       ['Blaze', 'Solar Power']
# 5       ['Blaze', 'Solar Power']
# 6       ['Blaze', 'Solar Power']
# 7                    ['Drought']
# 8                ['Tough Claws']
# 9       ['Rain Dish', 'Torrent']
# Name: Abilities, dtype: object
#                Name  Att  Standard Deviation
# 0         Bulbasaur   49            8.640988
# 1           Ivysaur   62            8.902247
# 2          Venusaur   82            8.902247
# 3     Mega Venusaur  100           18.747592
# 4        Charmander   52            8.995369
# 5        Charmeleon   64            9.233093
# 6         Charizard   84           11.575837
# 7  Mega Charizard Y  104           27.378012
# 8  Mega Charizard X  130           20.154955
# 9          Squirtle   48            8.919392

# %%
##printing each col name
for col in df.columns:
  print(col)

# %%
##read each col
print(df.iloc[0:4])
# Out:
#    Number           Name Type 1  Type 2  ... Against Fairy  Height  Weight   BMI
# 0       1      Bulbasaur  Grass  Poison  ...           0.5     0.7     6.9  14.1
# 1       2        Ivysaur  Grass  Poison  ...           0.5     1.0    13.0  13.0
# 2       3       Venusaur  Grass  Poison  ...           0.5     2.0   100.0  25.0
# 3       3  Mega Venusaur  Grass  Poison  ...           0.5     2.4   155.5  27.0
#
# [4 rows x 44 columns]

# %%
##by using the for loop 
for index, row in df.head(10).iterrows():
  print(index, row['Name'])
# Out:
# 0 Bulbasaur
# 1 Ivysaur
# 2 Venusaur
# 3 Mega Venusaur
# 4 Charmander
# 5 Charmeleon
# 6 Charizard
# 7 Mega Charizard Y
# 8 Mega Charizard X
# 9 Squirtle

# %%
df.head(10).loc[df['Type 1']=='Grass']
# Out:
#    Number           Name Type 1  Type 2  ... Against Fairy  Height  Weight   BMI
# 0       1      Bulbasaur  Grass  Poison  ...           0.5     0.7     6.9  14.1
# 1       2        Ivysaur  Grass  Poison  ...           0.5     1.0    13.0  13.0
# 2       3       Venusaur  Grass  Poison  ...           0.5     2.0   100.0  25.0
# 3       3  Mega Venusaur  Grass  Poison  ...           0.5     2.4   155.5  27.0
#
# [4 rows x 44 columns]

# %%
##reading the specific row and columns
print(df.iloc[2,1])
# Out:
# Venusaur

# %% [markdown]
# **Sorting/Describing Data**

# %%
df[['Name','HP']].sort_values(['Name','HP'], ascending=[0,1])
# Out:
#                      Name   HP
# 833      Zygarde Complete  216
# 832           Zygarde 10%   54
# 831               Zygarde  108
# 733              Zweilous   72
# 53                  Zubat   40
# ..                    ...  ...
# 788  Aegislash Blade Form   50
# 715              Accelgor   80
# 425                 Absol   65
# 80                   Abra   25
# 543             Abomasnow   90
#
# [1032 rows x 2 columns]

# %%
df.head(20)[['Name','Att','Def']].sort_values(['Att','Def'], ascending = [0,0])
# Out:
#                 Name  Att  Def
# 19     Mega Beedrill  150   40
# 8   Mega Charizard X  130  111
# 7   Mega Charizard Y  104   78
# 12    Mega Blastoise  103  120
# 3      Mega Venusaur  100  123
# 18          Beedrill   90   40
# 6          Charizard   84   78
# 11         Blastoise   83  100
# 2           Venusaur   82   83
# 5         Charmeleon   64   58
# 10         Wartortle   63   80
# 1            Ivysaur   62   63
# 4         Charmander   52   43
# 0          Bulbasaur   49   49
# 9           Squirtle   48   65
# 15        Butterfree   45   50
# 16            Weedle   35   30
# 13          Caterpie   30   35
# 17            Kakuna   25   50
# 14           Metapod   20   55

# %% [markdown]
# **Making changes in data**

# %%
#create new column 
df['Total'] = df['HP']+df['Att']+df['Def']
#df['Total']

df = df.drop(columns = ['Total'])#column deleted

cols = list(df.columns)
cols
# Out:
# ['Number',
#  'Name',
#  'Type 1',
#  'Type 2',
#  'Abilities',
#  'HP',
#  'Att',
#  'Def',
#  'Spa',
#  'Spd',
#  'Spe',
#  'BST',
#  'Mean',
#  'Standard Deviation',
#  'Generation',
#  'Experience type',
#  'Experience to level 100',
#  'Final Evolution',
#  'Catch Rate',
#  'Legendary',
#  'Mega Evolution',
#  'Alolan Form',
#  'Galarian Form',
#  'Against Normal',
#  'Against Fire',
#  'Against Water',
#  'Against Electric',
#  'Against Grass',
#  'Against Ice',
#  'Against Fighting',
#  'Against Poison',
#  'Against Ground',
#  'Against Flying',
#  'Against Psychic',
#  'Against Bug',
#  'Against Rock',
#  'Against Ghost',
#  'Against Dragon',
#  'Against Dark',
#  'Against Steel',
#  'Against Fairy',
#  'Height',
#  'Weight',
#  'BMI']

# %%
df1 = df[cols[0:4] + [cols[-1]] + cols[4:12]]
df1
# Out:
#       Number                  Name   Type 1  Type 2  ...  Spa  Spd  Spe  BST
# 0          1             Bulbasaur    Grass  Poison  ...   65   65   45  318
# 1          2               Ivysaur    Grass  Poison  ...   80   80   60  405
# 2          3              Venusaur    Grass  Poison  ...  100  100   80  525
# 3          3         Mega Venusaur    Grass  Poison  ...  122  120   80  625
# 4          4            Charmander     Fire     NaN  ...   60   50   65  309
# ...      ...                   ...      ...     ...  ...  ...  ...  ...  ...
# 1027     896             Glastrier      Ice     NaN  ...   65  110   30  580
# 1028     897             Spectrier    Ghost     NaN  ...  145   80  130  580
# 1029     898               Calyrex  Psychic   Grass  ...   80   80   80  500
# 1030     898     Calyrex Ice Rider  Psychic     Ice  ...   85  130   50  680
# 1031     898  Calyrex Shadow Rider  Psychic   Ghost  ...  165  100  150  680
#
# [1032 rows x 13 columns]

# %%
80+82+83+100+100+80
# Out:
# 525

# %% [markdown]
# **Saving our Data(Exporting into Desired Format)**

# %%
df.to_csv('modified.csv', index = False)

df.to_excel("modified_to_excel.xlsx", sheet_name="passengers", index=False)

df.to_csv('modified2.txt', index = False, sep= '\t')

# %%
df = pd.read_excel("modified_to_excel.xlsx", sheet_name="passengers")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1032 entries, 0 to 1031
# Data columns (total 44 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Number                   1032 non-null   int64
#  1   Name                     1032 non-null   object
#  2   Type 1                   1032 non-null   object
#  3   Type 2                   548 non-null    object
#  4   Abilities                1032 non-null   object
#  5   HP                       1032 non-null   int64
#  6   Att                      1032 non-null   int64
#  7   Def                      1032 non-null   int64
#  8   Spa                      1032 non-null   int64
#  9   Spd                      1032 non-null   int64
#  10  Spe                      1032 non-null   int64
#  11  BST                      1032 non-null   int64
#  12  Mean                     1032 non-null   float64
#  13  Standard Deviation       1032 non-null   float64
# ...

# %% [markdown]
# **Filtering data**

# %%
## filtering using the and as (&) ans or as (|)
new_df = df.loc[(df['Type 1']=='Grass') & (df['Type 2']=='Poison')]
new_df.reset_index(drop=True, inplace=True)
new_df.shape #using the shape to get the total number of rows and columns

new_df.to_csv('filtered.csv')

# %% [markdown]
# **conditional Changes**

# %%
#type(df.columns)
#isinstance(df.columns)
#df.head(5)

# %%
df.loc[df['Type 1']=='fire','Type 1']=True
df.head(23)
#df.loc[df['Total']>500, ['generation', Legendary]]==['Test 1','Test 2']
# Out:
#       Number                  Name   Type 1  ... Height Weight    BMI
# 1030     898     Calyrex Ice Rider  Psychic  ...    2.4  809.1  140.5
# 1031     898  Calyrex Shadow Rider  Psychic  ...    2.4   53.6    9.3
#
# [2 rows x 44 columns]

# %%
#df.loc[df['Att']>100, ['Generation','Legendary']] =['Test 1','Test 2']
#df
df = pd.read_csv('modified.csv')

# %% [markdown]
# **Aggregate Statistics(Groupby)**

# %%
df = pd.read_csv('modified.csv')


df['count'] = 1
df.groupby(['Type 1','Type 2']).count()['count']
# Out:
# Type 1  Type 2
# Bug     Electric     4
#         Fairy        2
#         Fighting     4
#         Fire         2
#         Flying      14
#                     ..
# Water   Ice          4
#         Poison       3
#         Psychic      6
#         Rock         5
#         Steel        1
# Name: count, Length: 174, dtype: int64

# %% [markdown]
# handling exception

# %%
import pandas as pd
import numpy as np


base = np.array([2,4,5,6])

try:
  base =='asdf'
except TypeError as e:
  print('TypeError:',str(e))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison

# %% [markdown]
# **Working with large amount of data**

# %%
new_df = pd.DataFrame(columns = df.columns)
new_df
# Out:
# Empty DataFrame
# Columns: [Number, Name, Type 1, Type 2, Abilities, HP, Att, Def, Spa, Spd, Spe, BST, Mean, Standard Deviation, Generation, Experience type, Experience to level 100, Final Evolution, Catch Rate, Legendary, Mega Evolution, Alolan Form, Galarian Form, Against Normal, Against Fire, Against Water, Against Electric, Against Grass, Against Ice, Against Fighting, Against Poison, Against Ground, Against Flying, Against Psychic, Against Bug, Against Rock, Against Ghost, Against Dragon, Against Dark, Against Steel, Against Fairy, Height, Weight, BMI, count]
# Index: []

# %%
for df in pd.read_csv('modified.csv', chunksize=2):
  result = df.groupby(['Type 1']).count()

  new_df = pd.concat([new_df, result])

# %%
new_df
# Out:
#         Number Name Type 1 Type 2  ... Height Weight BMI count
# Grass        2    2    NaN      2  ...      2      2   2   NaN
# Grass        2    2    NaN      2  ...      2      2   2   NaN
# Fire         2    2    NaN      0  ...      2      2   2   NaN
# Fire         2    2    NaN      2  ...      2      2   2   NaN
# Fire         1    1    NaN      1  ...      1      1   1   NaN
# ...        ...  ...    ...    ...  ...    ...    ...  ..   ...
# Dragon       1    1    NaN      0  ...      1      1   1   NaN
# Ice          1    1    NaN      0  ...      1      1   1   NaN
# Ghost        1    1    NaN      0  ...      1      1   1   NaN
# Psychic      1    1    NaN      1  ...      1      1   1   NaN
# Psychic      2    2    NaN      2  ...      2      2   2   NaN
#
# [759 rows x 45 columns]

# %%
df.groupby(['Type 1']).mean().sort_values('Att', ascending=True)
# Out:
#               Number         HP         Att  ...    Height      Weight          BMI
# Type 1                                       ...
# Fairy     541.772727  72.954545   68.090909  ...  0.927273   40.445455    19.263636
# Bug       399.691358  57.024691   71.074074  ...  0.896296   33.954321    41.258025
# Ghost     551.512195  62.731707   72.853659  ...  1.092683   49.592683    29.265854
# Electric  469.440678  62.389831   74.169492  ...  0.979661   38.920339    33.332203
# Grass     438.648352  66.736264   74.813187  ...  1.071429   39.839560    29.809890
# Poison    328.075000  70.475000   74.900000  ...  1.730000   60.917500    30.187500
# Water     374.450382  70.748092   74.923664  ...  1.454962   59.045038    33.547328
# Flying    752.750000  69.625000   75.125000  ...  1.112500   41.225000    30.437500
# Normal    382.719298  77.157895   75.263158  ...  1.021930   43.815789    34.882456
# Psychic   460.207792  73.714286   76.909091  ...  1.389610   79.496104  1324.009091
# ...

# %%
#df.groupby(['Type 1']).sum()
#fill empty column having NAN

#new_df['count'].isna()
new_df['count'].fillna(1)
# Out:
# Grass      1
# Grass      1
# Fire       1
# Fire       1
# Fire       1
#           ..
# Dragon     1
# Ice        1
# Ghost      1
# Psychic    1
# Psychic    1
# Name: count, Length: 759, dtype: int64

# %%
#loading the data with chunksize
for df in pd.read_csv('modified.csv', chunksize=5):
  print("chunk si")
  print(df)
  #result = df.groupby(['Type 1']).count()

  #new_df = pd.concat([new_df,result])
# Out:
# chunk si
#    Number           Name Type 1  Type 2  ... Against Fairy  Height  Weight   BMI
# 0       1      Bulbasaur  Grass  Poison  ...           0.5     0.7     6.9  14.1
# 1       2        Ivysaur  Grass  Poison  ...           0.5     1.0    13.0  13.0
# 2       3       Venusaur  Grass  Poison  ...           0.5     2.0   100.0  25.0
# 3       3  Mega Venusaur  Grass  Poison  ...           0.5     2.4   155.5  27.0
# 4       4     Charmander   Fire     NaN  ...           0.5     0.6     8.5  23.6
#
# [5 rows x 44 columns]
# chunk si
#    Number              Name Type 1  Type 2  ... Against Fairy  Height  Weight   BMI
# 5       5        Charmeleon   Fire     NaN  ...           0.5     1.1    19.0  15.7
# 6       6         Charizard   Fire  Flying  ...           0.5     1.7    90.5  31.3
# 7       6  Mega Charizard Y   Fire  Flying  ...           0.5     1.7   100.5  34.8
# 8       6  Mega Charizard X   Fire  Dragon  ...           1.0     1.7   110.5  38.2
# ...
